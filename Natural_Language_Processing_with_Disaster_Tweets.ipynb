# %%
import pandas as pd
import plotly.express as px

# %%
train = pd.read_csv('Dataset_Natural_Language_Processing_with_Disaster_Tweets/train.csv')
test = pd.read_csv('Dataset_Natural_Language_Processing_with_Disaster_Tweets/test.csv')

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print(train.shape[0], train.shape[1])
print(test.shape[0], test.shape[1])
# Out:
# 7613 5
# 3263 4

# %%
train['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
def length(x):
    return len(x)

# %%
train['length'] = train['text'].apply(length)

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target  length
# 0       1      69
# 1       1      38
# 2       1     133
# 3       1      65
# 4       1      88

# %%
fig = px.histogram(train, x = 'length', color = 'target', barmode='overlay', nbins = 100)
fig.show()

# %%
train[train['target'] == 0]['id']
# Out:
# 15         23
# 16         24
# 17         25
# 18         26
# 19         28
#         ...
# 7581    10833
# 7582    10834
# 7584    10837
# 7587    10841
# 7593    10848
# Name: id, Length: 4342, dtype: int64
